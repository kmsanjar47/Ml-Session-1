# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("Bank Data.csv")

# %%
df.head(5)
# Out:
#        ID Customer_ID      Month             Name  Age          SSN  \
# 0  0x160a   CUS_0xd40  September    Aaron Maashoh   23  821-00-0265
# 1  0x160b   CUS_0xd40    October    Aaron Maashoh   24  821-00-0265
# 2  0x160c   CUS_0xd40   November    Aaron Maashoh   24  821-00-0265
# 3  0x160d   CUS_0xd40   December    Aaron Maashoh  24_  821-00-0265
# 4  0x1616  CUS_0x21b1  September  Rick Rothackerj   28  004-07-5839
#
#   Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 0  Scientist      19114.12            1824.843333                  3  ...
# 1  Scientist      19114.12            1824.843333                  3  ...
# 2  Scientist      19114.12            1824.843333                  3  ...
# 3  Scientist      19114.12                    NaN                  3  ...
# 4    _______      34847.84            3037.986667                  2  ...
#
#    Num_Credit_Inquiries  Credit_Mix Outstanding_Debt Credit_Utilization_Ratio  \
# ...

# %%
df.tail(5)
# Out:
#             ID Customer_ID      Month            Name   Age          SSN  \
# 49995  0x25fe5  CUS_0x8600   December  Sarah McBridec  4975  031-35-0942
# 49996  0x25fee  CUS_0x942c  September           Nicks    25  078-73-5990
# 49997  0x25fef  CUS_0x942c    October           Nicks    25  078-73-5990
# 49998  0x25ff0  CUS_0x942c   November           Nicks    25  078-73-5990
# 49999  0x25ff1  CUS_0x942c   December           Nicks    25  078-73-5990
#
#       Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 49995  Architect      20002.88            1929.906667                 10  ...
# 49996   Mechanic      39628.99                    NaN                  4  ...
# 49997   Mechanic      39628.99            3359.415833                  4  ...
# 49998   Mechanic      39628.99                    NaN                  4  ...
# 49999   Mechanic      39628.99            3359.415833                  4  ...
#
# ...

# %%
df.shape
# Out:
# (50000, 27)

# %%
# dict["key"] = value
# df.iloc(:,:)
# df.loc()

# %%
# df.drop(["asda","dasdas"],axis = 1) # axis 1 : column, axis 0 : row
df2 = df.copy()

# %%
# df2 = df2.drop("ID",axis = 1)
df2.drop("ID",axis = 1, inplace = True)

# %%
df2
# Out:
#       Customer_ID      Month             Name   Age          SSN Occupation  \
# 0       CUS_0xd40  September    Aaron Maashoh    23  821-00-0265  Scientist
# 1       CUS_0xd40    October    Aaron Maashoh    24  821-00-0265  Scientist
# 2       CUS_0xd40   November    Aaron Maashoh    24  821-00-0265  Scientist
# 3       CUS_0xd40   December    Aaron Maashoh   24_  821-00-0265  Scientist
# 4      CUS_0x21b1  September  Rick Rothackerj    28  004-07-5839    _______
# ...           ...        ...              ...   ...          ...        ...
# 49995  CUS_0x8600   December   Sarah McBridec  4975  031-35-0942  Architect
# 49996  CUS_0x942c  September            Nicks    25  078-73-5990   Mechanic
# 49997  CUS_0x942c    October            Nicks    25  078-73-5990   Mechanic
# 49998  CUS_0x942c   November            Nicks    25  078-73-5990   Mechanic
# 49999  CUS_0x942c   December            Nicks    25  078-73-5990   Mechanic
#
# ...

# %%
df.dtypes #  Encoding
# Out:
# ID                           object
# Customer_ID                  object
# Month                        object
# Name                         object
# Age                          object
# SSN                          object
# Occupation                   object
# Annual_Income                object
# Monthly_Inhand_Salary       float64
# Num_Bank_Accounts             int64
# Num_Credit_Card               int64
# Interest_Rate                 int64
# Num_of_Loan                  object
# Type_of_Loan                 object
# Delay_from_due_date           int64
# Num_of_Delayed_Payment       object
# Changed_Credit_Limit         object
# Num_Credit_Inquiries        float64
# Credit_Mix                   object
# Outstanding_Debt             object
# Credit_Utilization_Ratio    float64
# Credit_History_Age           object
# Payment_of_Min_Amount        object
# Total_EMI_per_month         float64
# Amount_invested_monthly      object
# Payment_Behaviour            object
# ...

# %%
df.isna().sum() # Null Handling
# Out:
# ID                             0
# Customer_ID                    0
# Month                          0
# Name                        5015
# Age                            0
# SSN                            0
# Occupation                     0
# Annual_Income                  0
# Monthly_Inhand_Salary       7498
# Num_Bank_Accounts              0
# Num_Credit_Card                0
# Interest_Rate                  0
# Num_of_Loan                    0
# Type_of_Loan                5704
# Delay_from_due_date            0
# Num_of_Delayed_Payment      3498
# Changed_Credit_Limit           0
# Num_Credit_Inquiries        1035
# Credit_Mix                     0
# Outstanding_Debt               0
# Credit_Utilization_Ratio       0
# Credit_History_Age          4470
# Payment_of_Min_Amount          0
# Total_EMI_per_month            0
# Amount_invested_monthly     2271
# Payment_Behaviour              0
# Monthly_Balance              562
# dtype: int64

# %%
df.describe()
# Out:
#        Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# count           42502.000000       50000.000000     50000.000000
# mean             4182.004291          16.838260        22.921480
# std              3174.109304         116.396848       129.314804
# min               303.645417          -1.000000         0.000000
# 25%              1625.188333           3.000000         4.000000
# 50%              3086.305000           6.000000         5.000000
# 75%              5934.189094           7.000000         7.000000
# max             15204.633333        1798.000000      1499.000000
#
#        Interest_Rate  Delay_from_due_date  Num_Credit_Inquiries  \
# count   50000.000000         50000.000000          48965.000000
# mean       68.772640            21.052640             30.080200
# std       451.602363            14.860397            196.984121
# min         1.000000            -5.000000              0.000000
# ...

# %%
df.nunique() # To identify categorical and quantititive data
# Out:
# ID                          50000
# Customer_ID                 12500
# Month                           4
# Name                        10139
# Age                           976
# SSN                         12501
# Occupation                     16
# Annual_Income               16121
# Monthly_Inhand_Salary       12793
# Num_Bank_Accounts             540
# Num_Credit_Card               819
# Interest_Rate                 945
# Num_of_Loan                   263
# Type_of_Loan                 6260
# Delay_from_due_date            73
# Num_of_Delayed_Payment        443
# Changed_Credit_Limit         3927
# Num_Credit_Inquiries          750
# Credit_Mix                      4
# Outstanding_Debt            12685
# Credit_Utilization_Ratio    50000
# Credit_History_Age            399
# Payment_of_Min_Amount           3
# Total_EMI_per_month         13144
# Amount_invested_monthly     45450
# Payment_Behaviour               7
# Monthly_Balance             49433
# dtype: int64

# %%
# Correlation Matrix
corr = df.corr

# %%
corr
# Out:
# <bound method DataFrame.corr of             ID Customer_ID      Month             Name   Age          SSN  \
# 0       0x160a   CUS_0xd40  September    Aaron Maashoh    23  821-00-0265
# 1       0x160b   CUS_0xd40    October    Aaron Maashoh    24  821-00-0265
# 2       0x160c   CUS_0xd40   November    Aaron Maashoh    24  821-00-0265
# 3       0x160d   CUS_0xd40   December    Aaron Maashoh   24_  821-00-0265
# 4       0x1616  CUS_0x21b1  September  Rick Rothackerj    28  004-07-5839
# ...        ...         ...        ...              ...   ...          ...
# 49995  0x25fe5  CUS_0x8600   December   Sarah McBridec  4975  031-35-0942
# 49996  0x25fee  CUS_0x942c  September            Nicks    25  078-73-5990
# 49997  0x25fef  CUS_0x942c    October            Nicks    25  078-73-5990
# 49998  0x25ff0  CUS_0x942c   November            Nicks    25  078-73-5990
# 49999  0x25ff1  CUS_0x942c   December            Nicks    25  078-73-5990
#
# ...

# %%
# sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".3f", linewidths=0.5)
# plt.title("Correlation Matrix")
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".3f", linewidths=0.5)
#       2 plt.title("Correlation Matrix")
#       3 plt.show()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\seaborn\matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     443
#     444 """
#     445 # Initialize the plotter object
# --> 446 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                       annot_kws, cbar, cbar_kws, xticklabels,
# ...
